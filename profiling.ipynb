# %%
import jax.profiler
jax.profiler.start_server(9999)

# %%
# %run main_demo_v2.py
# Out:
# Whitening with representation (mean, std): (0.0000, 1.0016)
#     seed  samples    val_loss
# 0    0.0     10.0    5.852933
# 1    1.0     10.0   39.487923
# 2    2.0     10.0   19.315117
# 3    3.0     10.0  141.526154
# 4    4.0     10.0   25.102816
# 5    0.0     26.0    4.681108
# 6    1.0     26.0    4.635295
# 7    2.0     26.0    4.221467
# 8    3.0     26.0    4.126010
# 9    4.0     26.0    6.194371
# 10   0.0     68.0    1.500805
# 11   1.0     68.0    1.584610
# 12   2.0     68.0    2.011000
# 13   3.0     68.0    1.802239
# 14   4.0     68.0    1.521078
# 15   0.0    176.0    1.065863
# 16   1.0    176.0    1.099655
# 17   2.0    176.0    1.266196
# 18   3.0    176.0    1.322855
# 19   4.0    176.0    1.072647
# 20   0.0    456.0    0.778896
# 21   1.0    456.0    0.881319
# 22   2.0    456.0    0.852202
# 23   3.0    456.0    0.825794
# 24   4.0    456.0    0.913577
# 25   0.0   1185.0    0.500316
# 26   1.0   1185.0    0.540618
# 27   2.0   1185.0    0.536360
# ...
